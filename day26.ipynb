# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
data = pd.read_csv(r"Cars.csv")
data.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
data.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
data.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
data.drop('HP',axis=1).corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
sns.displot(data['MPG'])
# Out:
# C:\Users\PALADUGULLA KARTHIK\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data['VOL'])
# Out:
# C:\Users\PALADUGULLA KARTHIK\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data['SP'])
# Out:
# C:\Users\PALADUGULLA KARTHIK\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data['WT'])
# Out:
# C:\Users\PALADUGULLA KARTHIK\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import statsmodels.formula.api as smf
model = smf.ols("MPG~VOL~SP~WT", data=data).fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 import statsmodels.formula.api as smf
# ----> 2 model = smf.ols("MPG~VOL~SP~WT", data=data).fit()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\base\model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File ~\anaconda3\Lib\site-packages\statsmodels\formula\formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ...

# %%
sns.regplot(x="MPG", y="VOL", data=data,ci=None);

# %%
sns.regplot(x="SP", y="WT", data=data,ci=None);

# %%
sns.boxplot(data=[10,20,30,40,50])
# Out:
# <Axes: >

# %%
sns.scatterplot(x=data['VOL'],y=data['MPG'])
plt.show()

# %%
sns.scatterplot(x=data['SP'],y=data['VOL'])
plt.show()

# %%
data.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(data.corr(),cmap='Blues',annot=True)
plt.show()
